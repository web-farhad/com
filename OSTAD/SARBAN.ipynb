# %% [markdown]
# # Seaborn: statistical data visualization -- exercises overview
#
# Hi guys,<br>
#
# Great work! It's time to practice and test the skills you have just learned. <br>
#
# We will use **tips**, **iris** and another very famous dataset **titanic** for these exercises. These datasets are included in the seaborn's built-in dataset library.<br>
# Let's do some exploratory data analysis using seaborn and present useful plots for data visualization!<br>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Do the following tasks:**
# * set style to '`white`'
# * load titanic dataset into '`titanic`', tips into '`tips`' and iris into '`iris`'

# %%
# Code here and leave the next cell empty, so that you don't lose the plot!

# %%
# Task 1: Set the style to 'white'
sns.set_style('white')

# %%
# Code here and leave the next cell empty, so that you don't lose the plot!

# %%
# Task 2: Load the datasets
titanic = sns.load_dataset('titanic')
tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')

# %%
# Code here and leave the next cell empty, so that you don't lose the plot!

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
# Code here and leave the next cell empty, so that you don't lose the plot!

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Code here and leave the next cell empty, so that you don't lose the plot!

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **Recreate the plot below. Use tips dataset. Hint: pay attention to x and y labels.**

# %%
# Code here and leave the next cell empty, so that you don't lose the plot!

# %%
# Task 3: Recreate the boxplot using the 'tips' dataset
plt.figure(figsize=(8, 6))
sns.boxplot(x='day', y='total_bill', data=tips)
plt.xlabel('Day')
plt.ylabel('Total Bill')
plt.title('Boxplot of Total Bill by Day')
plt.show()

# %% [markdown]
# **Recreate the plot below. Use tips dataset. Hint: pay attention to x and y labels.**

# %%
# Code here and leave the next cell empty, so that you don't lose the plot!

# %%
# Task 4: Recreate the scatter plot using the 'tips' dataset
plt.figure(figsize=(8, 6))
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.title('Scatter plot of Tip vs Total Bill')
plt.show()

# %% [markdown]
# **Recreate the distplot given below. Use titanic dataset. Hint: pay attention to x and y labels.**

# %%
# Code here and leave the next cell empty, so that you don't lose the plot!

# %%
# Task 5: Recreate the distplot using the 'titanic' dataset
plt.figure(figsize=(8, 6))
sns.distplot(titanic['age'].dropna(), kde=False, bins=30)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age')
plt.show()
# Out:
# C:\Users\farha\AppData\Local\Temp\ipykernel_8792\1133258455.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['age'].dropna(), kde=False, bins=30)

# %% [markdown]
# **Recreate the boxplot below using titanic dataset. Hint: pay attention to x and y labels.**

# %%
# Code here and leave the next cell empty, so that you don't lose the plot!

# %%
# Task 6: Recreate the boxplot using the 'titanic' dataset
plt.figure(figsize=(8, 6))
sns.boxplot(x='class', y='age', data=titanic)
plt.xlabel('Class')
plt.ylabel('Age')
plt.title('Boxplot of Age by Class')
plt.show()

# %% [markdown]
# **Recreate the plot below using titanic dataset. Hint: pay attention to x and y labels.**

# %%
# Code here and leave the next cell empty, so that you don't lose the plot!

# %%
# Task 7: Recreate the scatter plot using the 'titanic' dataset
plt.figure(figsize=(8, 6))
sns.scatterplot(x='age', y='fare', hue='class', data=titanic)
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Scatter plot of Fare vs Age (colored by Class)')
plt.show()

# %% [markdown]
# **Recreate the plot below. Use titanic dataset. **

# %%
# Code here and leave the next cell empty, so that you don't lose the plot!

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='class', y='age', data=titanic)
plt.xlabel('Class')
plt.ylabel('Age')
plt.title('Boxplot of Age by Class')
plt.show()

# %% [markdown]
# **Can you plot how many male and female were on titanic? Separate them based on their class.**

# %%
# Code here and leave the next cell empty, so that you don't lose the plot!

# %%
# Task 8: Plot the count of males and females on the Titanic, separated by their class
plt.figure(figsize=(8, 6))
sns.countplot(x='class', hue='sex', data=titanic)
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Count of Males and Females by Class on Titanic')
plt.show()

# %% [markdown]
# **Recreate the plot below. Use titanic dataset. Hint: Matrix plots**

# %%
# Code here and leave the next cell empty, so that you don't lose the plot!

# %%
# Task 9: Recreate the matrix plot using the 'titanic' dataset
plt.figure(figsize=(8, 6))
sns.heatmap(titanic.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap of Titanic Dataset')
plt.show()
# Out:
# C:\Users\farha\AppData\Local\Temp\ipykernel_8792\386451497.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(), annot=True, cmap='coolwarm')

# %% [markdown]
# # Excellent work!
#
# **So far, we are done with the seaborn essentials. We will practice much more in the coming machine learning section!**
